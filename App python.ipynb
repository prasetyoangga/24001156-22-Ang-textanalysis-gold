# %%
# challenge API Flask
# !pip install flask

from flask import Flask

app = Flask('_name_')

@app.route('/my')
def my_name():
  return "Hello My Name is [NAMA ANDA}"

  if _name_ == "_main_":
    app.run(debug=True)

# %%
# Tugas ke 2
# !pip install gradio

import pandas as pd
import gradio as gr
import re

# Define a function to perform text cleansing
def clean_text(df):
 # Remove punctuation
  text = re.sub(r'[^\w\s]', '', text)

 # Return the cleaned text
  return text

# Create a Gradio interface
iface = gr.Interface(
    fn=clean_text,
    inputs=gr.File(label="Upload CSV File"),
    outputs=gr.Textbox(label="Cleaned Text Data"),
    title="Text Cleansing with Gradio",
    description="Upload a CSV file ."
)

# Launch the interface
iface.launch(debug=True)
# Out:
# ...
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://2f67fdf838551f0ec0.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2f67fdf838551f0ec0.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 521, in process_events
#     response = await route_utils.call_process_api(
# ...

# %%
# API Flask

from flask import Flask

app = Flask(__name__)

@app.route('/my')
def test():
    return 'Hello, My Name is Yani!'

if __name__ == '__main__':
    app.run()

# %%
#API Gradio

import re
import gradio as gr
import pandas as pd

def data_processing(file_obj):

    # Import file csv ke Pandas
    df = pd.read_csv(file_obj.name, sep=";")

    # Ambil teks yang akan diproses dalam format list
    texts = df['text'].astype(str).to_list()

    # Lakukan cleansing pada teks
    cleaned_text = []
    for text in texts:
        cleaned_text.append(re.sub(r'[^a-zA-Z0-9]', ' ', text))

    return cleaned_text


gradio_ui = gr.Interface(data_processing,
                            title="Data Processing and Modeling",
                            description="Aplikasi Web Data Processing dan Modeling",
                            inputs="file",
                            outputs="json")

gradio_ui.launch()
